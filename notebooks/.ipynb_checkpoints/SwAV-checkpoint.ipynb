# %%
import torch
model = torch.hub.load('facebookresearch/swav:main', 'resnet50')
# Out:
# Using cache found in /home/zdc6/.cache/torch/hub/facebookresearch_swav_main

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
img_dir = "../data/images"

# %%
import os

# %%
images = os.listdir(img_dir)

# %%
sorted(images)
# Out:
# ['val_0.JPEG',
#  'val_1.JPEG',
#  'val_10.JPEG',
#  'val_100.JPEG',
#  'val_1000.JPEG',
#  'val_1001.JPEG',
#  'val_1002.JPEG',
#  'val_1003.JPEG',
#  'val_1004.JPEG',
#  'val_1005.JPEG',
#  'val_1006.JPEG',
#  'val_1007.JPEG',
#  'val_1008.JPEG',
#  'val_1009.JPEG',
#  'val_101.JPEG',
#  'val_1010.JPEG',
#  'val_1011.JPEG',
#  'val_1012.JPEG',
#  'val_1013.JPEG',
#  'val_1014.JPEG',
#  'val_1015.JPEG',
#  'val_1016.JPEG',
#  'val_1017.JPEG',
#  'val_1018.JPEG',
#  'val_1019.JPEG',
#  'val_102.JPEG',
#  'val_1020.JPEG',
#  'val_1021.JPEG',
#  'val_1022.JPEG',
#  'val_1023.JPEG',
#  'val_1024.JPEG',
#  'val_1025.JPEG',
#  'val_1026.JPEG',
#  'val_1027.JPEG',
#  'val_1028.JPEG',
#  'val_1029.JPEG',
#  'val_103.JPEG',
#  'val_1030.JPEG',
#  'val_1031.JPEG',
#  'val_1032.JPEG',
#  'val_1033.JPEG',
#  'val_1034.JPEG',
#  'val_1035.JPEG',
#  'val_1036.JPEG',
#  'val_1037.JPEG',
#  'val_1038.JPEG',
#  'val_1039.JPEG',
#  'val_104.JPEG',
#  'val_1040.JPEG',
#  'val_1041.JPEG',
#  'val_1042.JPEG',
#  'val_1043.JPEG',
#  'val_1044.JPEG',
#  'val_1045.JPEG',
#  'val_1046.JPEG',
#  'val_1047.JPEG',
#  'val_1048.JPEG',
#  'val_1049.JPEG',
#  'val_105.JPEG',
#  'val_1050.JPEG',
#  'val_1051.JPEG',
#  'val_1052.JPEG',
#  'val_1053.JPEG',
#  'val_1054.JPEG',
#  'val_1055.JPEG',
#  'val_1056.JPEG',
#  'val_1057.JPEG',
#  'val_1058.JPEG',
#  'val_1059.JPEG',
#  'val_106.JPEG',
#  'val_1060.JPEG',
#  'val_1061.JPEG',
#  'val_1062.JPEG',
#  'val_1063.JPEG',
#  'val_1064.JPEG',
#  'val_1065.JPEG',
#  'val_1066.JPEG',
#  'val_1067.JPEG',
#  'val_1068.JPEG',
#  'val_1069.JPEG',
#  'val_107.JPEG',
#  'val_1070.JPEG',
#  'val_1071.JPEG',
#  'val_1072.JPEG',
#  'val_1073.JPEG',
#  'val_1074.JPEG',
#  'val_1075.JPEG',
#  'val_1076.JPEG',
#  'val_1077.JPEG',
#  'val_1078.JPEG',
#  'val_1079.JPEG',
#  'val_108.JPEG',
#  'val_1080.JPEG',
#  'val_1081.JPEG',
#  'val_1082.JPEG',
#  'val_1083.JPEG',
#  'val_1084.JPEG',
#  'val_1085.JPEG',
#  'val_1086.JPEG',
#  'val_1087.JPEG',
#  'val_1088.JPEG',
#  'val_1089.JPEG',
#  'val_109.JPEG',
#  'val_1090.JPEG',
#  'val_1091.JPEG',
#  'val_1092.JPEG',
#  'val_1093.JPEG',
#  'val_1094.JPEG',
#  'val_1095.JPEG',
#  'val_1096.JPEG',
#  'val_1097.JPEG',
#  'val_1098.JPEG',
#  'val_1099.JPEG',
#  'val_11.JPEG',
#  'val_110.JPEG',
#  'val_1100.JPEG',
#  'val_1101.JPEG',
#  'val_1102.JPEG',
#  'val_1103.JPEG',
#  'val_1104.JPEG',
#  'val_1105.JPEG',
#  'val_1106.JPEG',
#  'val_1107.JPEG',
#  'val_1108.JPEG',
#  'val_1109.JPEG',
#  'val_111.JPEG',
#  'val_1110.JPEG',
#  'val_1111.JPEG',
#  'val_1112.JPEG',
#  'val_1113.JPEG',
#  'val_1114.JPEG',
#  'val_1115.JPEG',
#  'val_1116.JPEG',
#  'val_1117.JPEG',
#  'val_1118.JPEG',
#  'val_1119.JPEG',
#  'val_112.JPEG',
#  'val_1120.JPEG',
#  'val_1121.JPEG',
#  'val_1122.JPEG',
#  'val_1123.JPEG',
#  'val_1124.JPEG',
#  'val_1125.JPEG',
#  'val_1126.JPEG',
#  'val_1127.JPEG',
#  'val_1128.JPEG',
#  'val_1129.JPEG',
#  'val_113.JPEG',
#  'val_1130.JPEG',
#  'val_1131.JPEG',
#  'val_1132.JPEG',
#  'val_1133.JPEG',
#  'val_1134.JPEG',
#  'val_1135.JPEG',
#  'val_1136.JPEG',
#  'val_1137.JPEG',
#  'val_1138.JPEG',
#  'val_1139.JPEG',
#  'val_114.JPEG',
#  'val_1140.JPEG',
#  'val_1141.JPEG',
#  'val_1142.JPEG',
#  'val_1143.JPEG',
#  'val_1144.JPEG',
#  'val_1145.JPEG',
#  'val_1146.JPEG',
#  'val_1147.JPEG',
#  'val_1148.JPEG',
#  'val_1149.JPEG',
#  'val_115.JPEG',
#  'val_1150.JPEG',
#  'val_1151.JPEG',
#  'val_1152.JPEG',
#  'val_1153.JPEG',
#  'val_1154.JPEG',
#  'val_1155.JPEG',
#  'val_1156.JPEG',
#  'val_1157.JPEG',
#  'val_1158.JPEG',
#  'val_1159.JPEG',
#  'val_116.JPEG',
#  'val_1160.JPEG',
#  'val_1161.JPEG',
#  'val_1162.JPEG',
#  'val_1163.JPEG',
#  'val_1164.JPEG',
#  'val_1165.JPEG',
#  'val_1166.JPEG',
#  'val_1167.JPEG',
#  'val_1168.JPEG',
#  'val_1169.JPEG',
#  'val_117.JPEG',
#  'val_1170.JPEG',
#  'val_1171.JPEG',
#  'val_1172.JPEG',
#  'val_1173.JPEG',
#  'val_1174.JPEG',
#  'val_1175.JPEG',
#  'val_1176.JPEG',
#  'val_1177.JPEG',
#  'val_1178.JPEG',
#  'val_1179.JPEG',
#  'val_118.JPEG',
#  'val_1180.JPEG',
#  'val_1181.JPEG',
#  'val_1182.JPEG',
#  'val_1183.JPEG',
#  'val_1184.JPEG',
#  'val_1185.JPEG',
#  'val_1186.JPEG',
#  'val_1187.JPEG',
#  'val_1188.JPEG',
#  'val_1189.JPEG',
#  'val_119.JPEG',
#  'val_1190.JPEG',
#  'val_1191.JPEG',
#  'val_1192.JPEG',
#  'val_1193.JPEG',
#  'val_1194.JPEG',
#  'val_1195.JPEG',
#  'val_1196.JPEG',
#  'val_1197.JPEG',
#  'val_1198.JPEG',
#  'val_1199.JPEG',
#  'val_12.JPEG',
#  'val_120.JPEG',
#  'val_1200.JPEG',
#  'val_1201.JPEG',
#  'val_1202.JPEG',
#  'val_1203.JPEG',
#  'val_1204.JPEG',
#  'val_1205.JPEG',
#  'val_1206.JPEG',
#  'val_1207.JPEG',
#  'val_1208.JPEG',
#  'val_1209.JPEG',
#  'val_121.JPEG',
#  'val_1210.JPEG',
#  'val_1211.JPEG',
#  'val_1212.JPEG',
#  'val_1213.JPEG',
#  'val_1214.JPEG',
#  'val_1215.JPEG',
#  'val_1216.JPEG',
#  'val_1217.JPEG',
#  'val_1218.JPEG',
#  'val_1219.JPEG',
#  'val_122.JPEG',
#  'val_1220.JPEG',
#  'val_1221.JPEG',
#  'val_1222.JPEG',
#  'val_1223.JPEG',
#  'val_1224.JPEG',
#  'val_1225.JPEG',
#  'val_1226.JPEG',
#  'val_1227.JPEG',
#  'val_1228.JPEG',
#  'val_1229.JPEG',
#  'val_123.JPEG',
#  'val_1230.JPEG',
#  'val_1231.JPEG',
#  'val_1232.JPEG',
#  'val_1233.JPEG',
#  'val_1234.JPEG',
#  'val_1235.JPEG',
#  'val_1236.JPEG',
#  'val_1237.JPEG',
#  'val_1238.JPEG',
#  'val_1239.JPEG',
#  'val_124.JPEG',
#  'val_1240.JPEG',
#  'val_1241.JPEG',
#  'val_1242.JPEG',
#  'val_1243.JPEG',
#  'val_1244.JPEG',
#  'val_1245.JPEG',
#  'val_1246.JPEG',
#  'val_1247.JPEG',
#  'val_1248.JPEG',
#  'val_1249.JPEG',
#  'val_125.JPEG',
#  'val_1250.JPEG',
#  'val_1251.JPEG',
#  'val_1252.JPEG',
#  'val_1253.JPEG',
#  'val_1254.JPEG',
#  'val_1255.JPEG',
#  'val_1256.JPEG',
#  'val_1257.JPEG',
#  'val_1258.JPEG',
#  'val_1259.JPEG',
#  'val_126.JPEG',
#  'val_1260.JPEG',
#  'val_1261.JPEG',
#  'val_1262.JPEG',
#  'val_1263.JPEG',
#  'val_1264.JPEG',
#  'val_1265.JPEG',
#  'val_1266.JPEG',
#  'val_1267.JPEG',
#  'val_1268.JPEG',
#  'val_1269.JPEG',
#  'val_127.JPEG',
#  'val_1270.JPEG',
#  'val_1271.JPEG',
#  'val_1272.JPEG',
#  'val_1273.JPEG',
#  'val_1274.JPEG',
#  'val_1275.JPEG',
#  'val_1276.JPEG',
#  'val_1277.JPEG',
#  'val_1278.JPEG',
#  'val_1279.JPEG',
#  'val_128.JPEG',
#  'val_1280.JPEG',
#  'val_1281.JPEG',
#  'val_1282.JPEG',
#  'val_1283.JPEG',
#  'val_1284.JPEG',
#  'val_1285.JPEG',
#  'val_1286.JPEG',
#  'val_1287.JPEG',
#  'val_1288.JPEG',
#  'val_1289.JPEG',
#  'val_129.JPEG',
#  'val_1290.JPEG',
#  'val_1291.JPEG',
#  'val_1292.JPEG',
#  'val_1293.JPEG',
#  'val_1294.JPEG',
#  'val_1295.JPEG',
#  'val_1296.JPEG',
#  'val_1297.JPEG',
#  'val_1298.JPEG',
#  'val_1299.JPEG',
#  'val_13.JPEG',
#  'val_130.JPEG',
#  'val_1300.JPEG',
#  'val_1301.JPEG',
#  'val_1302.JPEG',
#  'val_1303.JPEG',
#  'val_1304.JPEG',
#  'val_1305.JPEG',
#  'val_1306.JPEG',
#  'val_1307.JPEG',
#  'val_1308.JPEG',
#  'val_1309.JPEG',
#  'val_131.JPEG',
#  'val_1310.JPEG',
#  'val_1311.JPEG',
#  'val_1312.JPEG',
#  'val_1313.JPEG',
#  'val_1314.JPEG',
#  'val_1315.JPEG',
#  'val_1316.JPEG',
#  'val_1317.JPEG',
#  'val_1318.JPEG',
#  'val_1319.JPEG',
#  'val_132.JPEG',
#  'val_1320.JPEG',
#  'val_1321.JPEG',
#  'val_1322.JPEG',
#  'val_1323.JPEG',
#  'val_1324.JPEG',
#  'val_1325.JPEG',
#  'val_1326.JPEG',
#  'val_1327.JPEG',
#  'val_1328.JPEG',
#  'val_1329.JPEG',
#  'val_133.JPEG',
#  'val_1330.JPEG',
#  'val_1331.JPEG',
#  'val_1332.JPEG',
#  'val_1333.JPEG',
#  'val_1334.JPEG',
#  'val_1335.JPEG',
#  'val_1336.JPEG',
#  'val_1337.JPEG',
#  'val_1338.JPEG',
#  'val_1339.JPEG',
#  'val_134.JPEG',
#  'val_1340.JPEG',
#  'val_1341.JPEG',
#  'val_1342.JPEG',
#  'val_1343.JPEG',
#  'val_1344.JPEG',
#  'val_1345.JPEG',
#  'val_1346.JPEG',
#  'val_1347.JPEG',
#  'val_1348.JPEG',
#  'val_1349.JPEG',
#  'val_135.JPEG',
#  'val_1350.JPEG',
#  'val_1351.JPEG',
#  'val_1352.JPEG',
#  'val_1353.JPEG',
#  'val_1354.JPEG',
#  'val_1355.JPEG',
#  'val_1356.JPEG',
#  'val_1357.JPEG',
#  'val_1358.JPEG',
#  'val_1359.JPEG',
#  'val_136.JPEG',
#  'val_1360.JPEG',
#  'val_1361.JPEG',
#  'val_1362.JPEG',
#  'val_1363.JPEG',
#  'val_1364.JPEG',
#  'val_1365.JPEG',
#  'val_1366.JPEG',
#  'val_1367.JPEG',
#  'val_1368.JPEG',
#  'val_1369.JPEG',
#  'val_137.JPEG',
#  'val_1370.JPEG',
#  'val_1371.JPEG',
#  'val_1372.JPEG',
#  'val_1373.JPEG',
#  'val_1374.JPEG',
#  'val_1375.JPEG',
#  'val_1376.JPEG',
#  'val_1377.JPEG',
#  'val_1378.JPEG',
#  'val_1379.JPEG',
#  'val_138.JPEG',
#  'val_1380.JPEG',
#  'val_1381.JPEG',
#  'val_1382.JPEG',
#  'val_1383.JPEG',
#  'val_1384.JPEG',
#  'val_1385.JPEG',
#  'val_1386.JPEG',
#  'val_1387.JPEG',
#  'val_1388.JPEG',
#  'val_1389.JPEG',
#  'val_139.JPEG',
#  'val_1390.JPEG',
#  'val_1391.JPEG',
#  'val_1392.JPEG',
#  'val_1393.JPEG',
#  'val_1394.JPEG',
#  'val_1395.JPEG',
#  'val_1396.JPEG',
#  'val_1397.JPEG',
#  'val_1398.JPEG',
#  'val_1399.JPEG',
#  'val_14.JPEG',
#  'val_140.JPEG',
#  'val_1400.JPEG',
#  'val_1401.JPEG',
#  'val_1402.JPEG',
#  'val_1403.JPEG',
#  'val_1404.JPEG',
#  'val_1405.JPEG',
#  'val_1406.JPEG',
#  'val_1407.JPEG',
#  'val_1408.JPEG',
#  'val_1409.JPEG',
#  'val_141.JPEG',
#  'val_1410.JPEG',
#  'val_1411.JPEG',
#  'val_1412.JPEG',
#  'val_1413.JPEG',
#  'val_1414.JPEG',
#  'val_1415.JPEG',
#  'val_1416.JPEG',
#  'val_1417.JPEG',
#  'val_1418.JPEG',
#  'val_1419.JPEG',
#  'val_142.JPEG',
#  'val_1420.JPEG',
#  'val_1421.JPEG',
#  'val_1422.JPEG',
#  'val_1423.JPEG',
#  'val_1424.JPEG',
#  'val_1425.JPEG',
#  'val_1426.JPEG',
#  'val_1427.JPEG',
#  'val_1428.JPEG',
#  'val_1429.JPEG',
#  'val_143.JPEG',
#  'val_1430.JPEG',
#  'val_1431.JPEG',
#  'val_1432.JPEG',
#  'val_1433.JPEG',
#  'val_1434.JPEG',
#  'val_1435.JPEG',
#  'val_1436.JPEG',
#  'val_1437.JPEG',
#  'val_1438.JPEG',
#  'val_1439.JPEG',
#  'val_144.JPEG',
#  'val_1440.JPEG',
#  'val_1441.JPEG',
#  'val_1442.JPEG',
#  'val_1443.JPEG',
#  'val_1444.JPEG',
#  'val_1445.JPEG',
#  'val_1446.JPEG',
#  'val_1447.JPEG',
#  'val_1448.JPEG',
#  'val_1449.JPEG',
#  'val_145.JPEG',
#  'val_1450.JPEG',
#  'val_1451.JPEG',
#  'val_1452.JPEG',
#  'val_1453.JPEG',
#  'val_1454.JPEG',
#  'val_1455.JPEG',
#  'val_1456.JPEG',
#  'val_1457.JPEG',
#  'val_1458.JPEG',
#  'val_1459.JPEG',
#  'val_146.JPEG',
#  'val_1460.JPEG',
#  'val_1461.JPEG',
#  'val_1462.JPEG',
#  'val_1463.JPEG',
#  'val_1464.JPEG',
#  'val_1465.JPEG',
#  'val_1466.JPEG',
#  'val_1467.JPEG',
#  'val_1468.JPEG',
#  'val_1469.JPEG',
#  'val_147.JPEG',
#  'val_1470.JPEG',
#  'val_1471.JPEG',
#  'val_1472.JPEG',
#  'val_1473.JPEG',
#  'val_1474.JPEG',
#  'val_1475.JPEG',
#  'val_1476.JPEG',
#  'val_1477.JPEG',
#  'val_1478.JPEG',
#  'val_1479.JPEG',
#  'val_148.JPEG',
#  'val_1480.JPEG',
#  'val_1481.JPEG',
#  'val_1482.JPEG',
#  'val_1483.JPEG',
#  'val_1484.JPEG',
#  'val_1485.JPEG',
#  'val_1486.JPEG',
#  'val_1487.JPEG',
#  'val_1488.JPEG',
#  'val_1489.JPEG',
#  'val_149.JPEG',
#  'val_1490.JPEG',
#  'val_1491.JPEG',
#  'val_1492.JPEG',
#  'val_1493.JPEG',
#  'val_1494.JPEG',
#  'val_1495.JPEG',
#  'val_1496.JPEG',
#  'val_1497.JPEG',
#  'val_1498.JPEG',
#  'val_1499.JPEG',
#  'val_15.JPEG',
#  'val_150.JPEG',
#  'val_1500.JPEG',
#  'val_1501.JPEG',
#  'val_1502.JPEG',
#  'val_1503.JPEG',
#  'val_1504.JPEG',
#  'val_1505.JPEG',
#  'val_1506.JPEG',
#  'val_1507.JPEG',
#  'val_1508.JPEG',
#  'val_1509.JPEG',
#  'val_151.JPEG',
#  'val_1510.JPEG',
#  'val_1511.JPEG',
#  'val_1512.JPEG',
#  'val_1513.JPEG',
#  'val_1514.JPEG',
#  'val_1515.JPEG',
#  'val_1516.JPEG',
#  'val_1517.JPEG',
#  'val_1518.JPEG',
#  'val_1519.JPEG',
#  'val_152.JPEG',
#  'val_1520.JPEG',
#  'val_1521.JPEG',
#  'val_1522.JPEG',
#  'val_1523.JPEG',
#  'val_1524.JPEG',
#  'val_1525.JPEG',
#  'val_1526.JPEG',
#  'val_1527.JPEG',
#  'val_1528.JPEG',
#  'val_1529.JPEG',
#  'val_153.JPEG',
#  'val_1530.JPEG',
#  'val_1531.JPEG',
#  'val_1532.JPEG',
#  'val_1533.JPEG',
#  'val_1534.JPEG',
#  'val_1535.JPEG',
#  'val_1536.JPEG',
#  'val_1537.JPEG',
#  'val_1538.JPEG',
#  'val_1539.JPEG',
#  'val_154.JPEG',
#  'val_1540.JPEG',
#  'val_1541.JPEG',
#  'val_1542.JPEG',
#  'val_1543.JPEG',
#  'val_1544.JPEG',
#  'val_1545.JPEG',
#  'val_1546.JPEG',
#  'val_1547.JPEG',
#  'val_1548.JPEG',
#  'val_1549.JPEG',
#  'val_155.JPEG',
#  'val_1550.JPEG',
#  'val_1551.JPEG',
#  'val_1552.JPEG',
#  'val_1553.JPEG',
#  'val_1554.JPEG',
#  'val_1555.JPEG',
#  'val_1556.JPEG',
#  'val_1557.JPEG',
#  'val_1558.JPEG',
#  'val_1559.JPEG',
#  'val_156.JPEG',
#  'val_1560.JPEG',
#  'val_1561.JPEG',
#  'val_1562.JPEG',
#  'val_1563.JPEG',
#  'val_1564.JPEG',
#  'val_1565.JPEG',
#  'val_1566.JPEG',
#  'val_1567.JPEG',
#  'val_1568.JPEG',
#  'val_1569.JPEG',
#  'val_157.JPEG',
#  'val_1570.JPEG',
#  'val_1571.JPEG',
#  'val_1572.JPEG',
#  'val_1573.JPEG',
#  'val_1574.JPEG',
#  'val_1575.JPEG',
#  'val_1576.JPEG',
#  'val_1577.JPEG',
#  'val_1578.JPEG',
#  'val_1579.JPEG',
#  'val_158.JPEG',
#  'val_1580.JPEG',
#  'val_1581.JPEG',
#  'val_1582.JPEG',
#  'val_1583.JPEG',
#  'val_1584.JPEG',
#  'val_1585.JPEG',
#  'val_1586.JPEG',
#  'val_1587.JPEG',
#  'val_1588.JPEG',
#  'val_1589.JPEG',
#  'val_159.JPEG',
#  'val_1590.JPEG',
#  'val_1591.JPEG',
#  'val_1592.JPEG',
#  'val_1593.JPEG',
#  'val_1594.JPEG',
#  'val_1595.JPEG',
#  'val_1596.JPEG',
#  'val_1597.JPEG',
#  'val_1598.JPEG',
#  'val_1599.JPEG',
#  'val_16.JPEG',
#  'val_160.JPEG',
#  'val_1600.JPEG',
#  'val_1601.JPEG',
#  'val_1602.JPEG',
#  'val_1603.JPEG',
#  'val_1604.JPEG',
#  'val_1605.JPEG',
#  'val_1606.JPEG',
#  'val_1607.JPEG',
#  'val_1608.JPEG',
#  'val_1609.JPEG',
#  'val_161.JPEG',
#  'val_1610.JPEG',
#  'val_1611.JPEG',
#  'val_1612.JPEG',
#  'val_1613.JPEG',
#  'val_1614.JPEG',
#  'val_1615.JPEG',
#  'val_1616.JPEG',
#  'val_1617.JPEG',
#  'val_1618.JPEG',
#  'val_1619.JPEG',
#  'val_162.JPEG',
#  'val_1620.JPEG',
#  'val_1621.JPEG',
#  'val_1622.JPEG',
#  'val_1623.JPEG',
#  'val_1624.JPEG',
#  'val_1625.JPEG',
#  'val_1626.JPEG',
#  'val_1627.JPEG',
#  'val_1628.JPEG',
#  'val_1629.JPEG',
#  'val_163.JPEG',
#  'val_1630.JPEG',
#  'val_1631.JPEG',
#  'val_1632.JPEG',
#  'val_1633.JPEG',
#  'val_1634.JPEG',
#  'val_1635.JPEG',
#  'val_1636.JPEG',
#  'val_1637.JPEG',
#  'val_1638.JPEG',
#  'val_1639.JPEG',
#  'val_164.JPEG',
#  'val_1640.JPEG',
#  'val_1641.JPEG',
#  'val_1642.JPEG',
#  'val_1643.JPEG',
#  'val_1644.JPEG',
#  'val_1645.JPEG',
#  'val_1646.JPEG',
#  'val_1647.JPEG',
#  'val_1648.JPEG',
#  'val_1649.JPEG',
#  'val_165.JPEG',
#  'val_1650.JPEG',
#  'val_1651.JPEG',
#  'val_1652.JPEG',
#  'val_1653.JPEG',
#  'val_1654.JPEG',
#  'val_1655.JPEG',
#  'val_1656.JPEG',
#  'val_1657.JPEG',
#  'val_1658.JPEG',
#  'val_1659.JPEG',
#  'val_166.JPEG',
#  'val_1660.JPEG',
#  'val_1661.JPEG',
#  'val_1662.JPEG',
#  'val_1663.JPEG',
#  'val_1664.JPEG',
#  'val_1665.JPEG',
#  'val_1666.JPEG',
#  'val_1667.JPEG',
#  'val_1668.JPEG',
#  'val_1669.JPEG',
#  'val_167.JPEG',
#  'val_1670.JPEG',
#  'val_1671.JPEG',
#  'val_1672.JPEG',
#  'val_1673.JPEG',
#  'val_1674.JPEG',
#  'val_1675.JPEG',
#  'val_1676.JPEG',
#  'val_1677.JPEG',
#  'val_1678.JPEG',
#  'val_1679.JPEG',
#  'val_168.JPEG',
#  'val_1680.JPEG',
#  'val_1681.JPEG',
#  'val_1682.JPEG',
#  'val_1683.JPEG',
#  'val_1684.JPEG',
#  'val_1685.JPEG',
#  'val_1686.JPEG',
#  'val_1687.JPEG',
#  'val_1688.JPEG',
#  'val_1689.JPEG',
#  'val_169.JPEG',
#  'val_1690.JPEG',
#  'val_1691.JPEG',
#  'val_1692.JPEG',
#  'val_1693.JPEG',
#  'val_1694.JPEG',
#  'val_1695.JPEG',
#  'val_1696.JPEG',
#  'val_1697.JPEG',
#  'val_1698.JPEG',
#  'val_1699.JPEG',
#  'val_17.JPEG',
#  'val_170.JPEG',
#  'val_1700.JPEG',
#  'val_1701.JPEG',
#  'val_1702.JPEG',
#  'val_1703.JPEG',
#  'val_1704.JPEG',
#  'val_1705.JPEG',
#  'val_1706.JPEG',
#  'val_1707.JPEG',
#  'val_1708.JPEG',
#  'val_1709.JPEG',
#  'val_171.JPEG',
#  'val_1710.JPEG',
#  'val_1711.JPEG',
#  'val_1712.JPEG',
#  'val_1713.JPEG',
#  'val_1714.JPEG',
#  'val_1715.JPEG',
#  'val_1716.JPEG',
#  'val_1717.JPEG',
#  'val_1718.JPEG',
#  'val_1719.JPEG',
#  'val_172.JPEG',
#  'val_1720.JPEG',
#  'val_1721.JPEG',
#  'val_1722.JPEG',
#  'val_1723.JPEG',
#  'val_1724.JPEG',
#  'val_1725.JPEG',
#  'val_1726.JPEG',
#  'val_1727.JPEG',
#  'val_1728.JPEG',
#  'val_1729.JPEG',
#  'val_173.JPEG',
#  'val_1730.JPEG',
#  'val_1731.JPEG',
#  'val_1732.JPEG',
#  'val_1733.JPEG',
#  'val_1734.JPEG',
#  'val_1735.JPEG',
#  'val_1736.JPEG',
#  'val_1737.JPEG',
#  'val_1738.JPEG',
#  'val_1739.JPEG',
#  'val_174.JPEG',
#  'val_1740.JPEG',
#  'val_1741.JPEG',
#  'val_1742.JPEG',
#  'val_1743.JPEG',
#  'val_1744.JPEG',
#  'val_1745.JPEG',
#  'val_1746.JPEG',
#  'val_1747.JPEG',
#  'val_1748.JPEG',
#  'val_1749.JPEG',
#  'val_175.JPEG',
#  'val_1750.JPEG',
#  'val_1751.JPEG',
#  'val_1752.JPEG',
#  'val_1753.JPEG',
#  'val_1754.JPEG',
#  'val_1755.JPEG',
#  'val_1756.JPEG',
#  'val_1757.JPEG',
#  'val_1758.JPEG',
#  'val_1759.JPEG',
#  'val_176.JPEG',
#  'val_1760.JPEG',
#  'val_1761.JPEG',
#  'val_1762.JPEG',
#  'val_1763.JPEG',
#  'val_1764.JPEG',
#  'val_1765.JPEG',
#  'val_1766.JPEG',
#  'val_1767.JPEG',
#  'val_1768.JPEG',
#  'val_1769.JPEG',
#  'val_177.JPEG',
#  'val_1770.JPEG',
#  'val_1771.JPEG',
#  'val_1772.JPEG',
#  'val_1773.JPEG',
#  'val_1774.JPEG',
#  'val_1775.JPEG',
#  'val_1776.JPEG',
#  'val_1777.JPEG',
#  'val_1778.JPEG',
#  'val_1779.JPEG',
#  'val_178.JPEG',
#  'val_1780.JPEG',
#  'val_1781.JPEG',
#  'val_1782.JPEG',
#  'val_1783.JPEG',
#  'val_1784.JPEG',
#  'val_1785.JPEG',
#  'val_1786.JPEG',
#  'val_1787.JPEG',
#  'val_1788.JPEG',
#  'val_1789.JPEG',
#  'val_179.JPEG',
#  'val_1790.JPEG',
#  'val_1791.JPEG',
#  'val_1792.JPEG',
#  'val_1793.JPEG',
#  'val_1794.JPEG',
#  'val_1795.JPEG',
#  'val_1796.JPEG',
#  'val_1797.JPEG',
#  'val_1798.JPEG',
#  'val_1799.JPEG',
#  'val_18.JPEG',
#  'val_180.JPEG',
#  'val_1800.JPEG',
#  'val_1801.JPEG',
#  'val_1802.JPEG',
#  'val_1803.JPEG',
#  'val_1804.JPEG',
#  'val_1805.JPEG',
#  'val_1806.JPEG',
#  'val_1807.JPEG',
#  'val_1808.JPEG',
#  'val_1809.JPEG',
#  'val_181.JPEG',
#  'val_1810.JPEG',
#  'val_1811.JPEG',
#  'val_1812.JPEG',
#  'val_1813.JPEG',
#  'val_1814.JPEG',
#  'val_1815.JPEG',
#  'val_1816.JPEG',
#  'val_1817.JPEG',
#  'val_1818.JPEG',
#  'val_1819.JPEG',
#  'val_182.JPEG',
#  'val_1820.JPEG',
#  'val_1821.JPEG',
#  'val_1822.JPEG',
#  'val_1823.JPEG',
#  'val_1824.JPEG',
#  'val_1825.JPEG',
#  'val_1826.JPEG',
#  'val_1827.JPEG',
#  'val_1828.JPEG',
#  'val_1829.JPEG',
#  'val_183.JPEG',
#  'val_1830.JPEG',
#  'val_1831.JPEG',
#  'val_1832.JPEG',
#  'val_1833.JPEG',
#  'val_1834.JPEG',
#  'val_1835.JPEG',
#  'val_1836.JPEG',
#  'val_1837.JPEG',
#  'val_1838.JPEG',
#  'val_1839.JPEG',
#  'val_184.JPEG',
#  'val_1840.JPEG',
#  'val_1841.JPEG',
#  'val_1842.JPEG',
#  'val_1843.JPEG',
#  'val_1844.JPEG',
#  'val_1845.JPEG',
#  'val_1846.JPEG',
#  'val_1847.JPEG',
#  'val_1848.JPEG',
#  'val_1849.JPEG',
#  'val_185.JPEG',
#  'val_1850.JPEG',
#  'val_1851.JPEG',
#  'val_1852.JPEG',
#  'val_1853.JPEG',
#  'val_1854.JPEG',
#  'val_1855.JPEG',
#  'val_1856.JPEG',
#  'val_1857.JPEG',
#  'val_1858.JPEG',
#  'val_1859.JPEG',
#  'val_186.JPEG',
#  'val_1860.JPEG',
#  'val_1861.JPEG',
#  'val_1862.JPEG',
#  'val_1863.JPEG',
#  'val_1864.JPEG',
#  'val_1865.JPEG',
#  'val_1866.JPEG',
#  'val_1867.JPEG',
#  'val_1868.JPEG',
#  'val_1869.JPEG',
#  'val_187.JPEG',
#  'val_1870.JPEG',
#  'val_1871.JPEG',
#  'val_1872.JPEG',
#  'val_1873.JPEG',
#  'val_1874.JPEG',
#  'val_1875.JPEG',
#  'val_1876.JPEG',
#  'val_1877.JPEG',
#  'val_1878.JPEG',
#  'val_1879.JPEG',
#  'val_188.JPEG',
#  'val_1880.JPEG',
#  'val_1881.JPEG',
#  'val_1882.JPEG',
#  'val_1883.JPEG',
#  'val_1884.JPEG',
#  'val_1885.JPEG',
#  'val_1886.JPEG',
#  'val_1887.JPEG',
#  'val_1888.JPEG',
#  'val_1889.JPEG',
#  'val_189.JPEG',
#  'val_1890.JPEG',
#  'val_1891.JPEG',
#  'val_1892.JPEG',
#  'val_1893.JPEG',
#  'val_1894.JPEG',
#  'val_1895.JPEG',
#  'val_1896.JPEG',
#  'val_1897.JPEG',
#  'val_1898.JPEG',
#  ...]

# %%
with open(img_dir+images[0], 'r') as f:
    t = f

# %%
# Out:
# <_io.TextIOWrapper name='../data/images/val_7054.JPEG' mode='r' encoding='UTF-8'>

# %%
from torchvision import datasets, transforms

# %%
data = datasets.ImageFolder("../data/images/")#, transform=transform)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-4db8b4138f98> in <module>
# ----> 1 data = datasets.ImageFolder("../data/images/")#, transform=transform)
#
# /usr/lib/python3/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     308             is_valid_file: Optional[Callable[[str], bool]] = None,
#     309     ):
# --> 310         super(ImageFolder, self).__init__(root, loader, IMG_EXTENSIONS if is_valid_file is None else None,
#     311                                           transform=transform,
#     312                                           target_transform=target_transform,
#
# /usr/lib/python3/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     143         super(DatasetFolder, self).__init__(root, transform=transform,
#     144                                             target_transform=target_transform)
# --> 145         classes, class_to_idx = self.find_classes(self.root)
#     146         samples = self.make_dataset(self.root, class_to_idx, extensions, is_valid_file)
#     147
#
# /usr/lib/python3/dist-packages/torchvision/datasets/folder.py in find_classes(self, directory)
#     219             (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     220         """
# --> 221         return find_classes(directory)
#     222
#     223     def __getitem__(self, index: int) -> Tuple[Any, Any]:
#
# /usr/lib/python3/dist-packages/torchvision/datasets/folder.py in find_classes(directory)
#      40     classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      41     if not classes:
# ---> 42         raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#      43
#      44     class_to_idx = {cls_name: i for i, cls_name in enumerate(classes)}
#
# FileNotFoundError: Couldn't find any class folder in ../data/images/.

# %%
transforms.to_tensor()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-ccf365d595bf> in <module>
# ----> 1 os.pwd()
#
# AttributeError: module 'os' has no attribute 'pwd'

# %%
from PIL import Image

# %%
im = Image.open(r"../data/images/val_1022.JPEG")

# %%
im.show()
